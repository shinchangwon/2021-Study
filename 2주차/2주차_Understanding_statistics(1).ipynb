# %% [markdown]
# 분포 함수
# - 분포함수 이해를 위해서는 연속 함수의 개념을 이해하는 것이 필수
# - 연속함수는 기본적으로 예기치 않은 값 변화가 없는 함수입니다.
# - 불연속함수는 이러한 갑작 스럽거나 예상치 못한 변경이 있는 함수
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 확률밀도함수(PDF, probability density function)

# %%
print('1~100','합산', sep='\n')
# Out:
# 1~100
# 합산

# %%
total = 0
for i in range (1, 101):
   total = total + i
print(total)
# Out:
# 5050

# %%
print(format(total, ","))
# Out:
# 5,050
